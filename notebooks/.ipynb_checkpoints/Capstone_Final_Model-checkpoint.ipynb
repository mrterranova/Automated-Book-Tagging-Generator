# %%
# !pip uninstall -y keras tensorflow
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install transformers
# !pip install transformers datasets torch
# !pip install --upgrade --force-reinstall pyarrow==16.1.0 --no-deps -q
# !pip install -U transformers datasets accelerate

# import importlib, pyarrow
# importlib.reload(pyarrow)

from datasets import Dataset
# Out:
# WARNING: Skipping keras as it is not installed.
# WARNING: Skipping tensorflow as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import torch

# !pip install ipywidgets
# jupyter nbextension enable --py widgetsnbextension --sys-prefix
# !pip install jupyterlab_widgets

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV

# Import dataset from final_data_version.csv
df_balanced = pd.read_csv("../data/final_data_version.csv")

# Split my data
(X_train, X_test, y_train, y_test) = train_test_split(df_balanced.description, df_balanced.category, test_size=0.2, random_state=42)

# %%
# Prepare data
le = LabelEncoder()
df_balanced['label'] = le.fit_transform(df_balanced['category'])

# Include title and author metadata
df_balanced['full_text'] = (
    df_balanced['title'] + ' by ' +
    df_balanced['authors'] + ': ' +
    df_balanced['description']
)

# Ensure correct column name
X_train, X_test, y_train, y_test = train_test_split(
    df_balanced['full_text'],
    df_balanced['label'],
    test_size=0.2,
    stratify=df_balanced['label'],
    random_state=42
)

# Convert to Hugging Face Datasets
train_dataset = Dataset.from_dict({'text': X_train.tolist(), 'label': y_train.tolist()})
test_dataset  = Dataset.from_dict({'text': X_test.tolist(),  'label': y_test.tolist()})

# %%
# Experiment using the roBERTa - include metadata

# roberta Model
roberta_model_epochs = "roberta-base"

tokenizer_roberta_epochs = AutoTokenizer.from_pretrained(roberta_model_epochs)

def tokenize(batch):
    return tokenizer_roberta_epochs(batch['text'], padding='max_length', truncation=True, max_length=256)

train_dataset = train_dataset.map(tokenize, batched=True)
test_dataset  = test_dataset.map(tokenize, batched=True)

train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
# Load model
num_labels = len(le.classes_)
model = AutoModelForSequenceClassification.from_pretrained(roberta_model_epochs, num_labels=num_labels)

# Training config
training_args = TrainingArguments(
    output_dir="./results",
    do_eval=True,   
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,   
    metric_for_best_model="f1", 
    greater_is_better=True,
    num_train_epochs=2,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=3e-5,
    weight_decay=0.01,
    warmup_ratio=0.1, 
    logging_dir="./logs",
    logging_steps=100,
    save_total_limit=2,
    report_to="none" 
)

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "precision": precision_score(labels, preds, average="weighted"),
        "recall": recall_score(labels, preds, average="weighted"),
        "f1": f1_score(labels, preds, average="weighted"),
    }


# Trainer
trainer_roberta_epochs = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer_roberta_epochs,
    compute_metrics=compute_metrics 
)

# Train
trainer_roberta_epochs.train()
# Out:
# ...
# Map:   0%|          | 0/9648 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /var/folders/gs/rm1mjp5x5ybc93h8m4xwbfyr0000gn/T/ipykernel_47562/3650054521.py:53: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer_roberta_epochs = Trainer(
# /opt/anaconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
# ...

# %%
# Save model
trainer_roberta_epochs.save_model("./final_model")
tokenizer_roberta_epochs.save_pretrained("./final_model")
# Out:
# ('./final_model/tokenizer_config.json',
#  './final_model/special_tokens_map.json',
#  './final_model/vocab.json',
#  './final_model/merges.txt',
#  './final_model/added_tokens.json',
#  './final_model/tokenizer.json')

# %%
# Evaluate roBERTa Model
preds_output_roberta_epochs = trainer_roberta_epochs.predict(test_dataset)
y_pred_roberta_epochs = preds_output_roberta_epochs.predictions.argmax(axis=1)
print(classification_report(y_test, y_pred_roberta_epochs, target_names=le.classes_))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                        precision    recall  f1-score   support
#
#                   art       0.71      0.72      0.72      1000
#      business/finance       0.86      0.82      0.84       923
#        fantasy/horror       0.68      0.70      0.69      1000
#                  food       0.87      0.81      0.83       891
#               history       0.71      0.74      0.72      1000
# religion/spirituality       0.75      0.77      0.76      1000
#               romance       0.78      0.80      0.79      1000
#               science       0.74      0.72      0.73      1000
#       science fiction       0.74      0.71      0.73       966
#              thriller       0.74      0.77      0.76       868
#
# ...

# %%
# Confusion matrix roBERTa

cm = confusion_matrix(y_test, y_pred_roberta_epochs, labels=range(len(le.classes_)))
plt.figure(figsize=(12,8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_,
            yticklabels=le.classes_, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - roBERTa')
plt.show()

# %%
# !pip install wordcloud
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
# Word Cloud

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Custom word stops that are common between categories to remove meaningless words
custom_words = {
    'book', 'books', 'story', 'stories', 'novel', 'author', 'writes', 'written',
    'one', 'also', 'many', 'would', 'could', 'may', 'might', 'like', 'well',
    'plot', 'said', 'told', 'made', 'make', 'every', 'around', 'across', 'within',
    'even', 'though', 'however', 'still', 'good', 'new', 'time', 'life', 'way',
    'chapter', 'read', 'reading', 'reader', 'series', 'pages', 'page', 'one', 'hes',
    'shes', 'she', 'he', 'will', 'work', 'now', 'will', 'first', 'world'
}

# Define stopwords
stopwords = set(STOPWORDS)
stopwords.update(custom_words)

# Function to generate a word cloud for a given category
def print_wordCloud(category, text):
    if not text.strip():
        print(f"No data for category: {category}")
        return
    print(f"Word Cloud for {category}")
    wordcloud = WordCloud(
        width=400,
        height=400,
        background_color='white',
        stopwords=stopwords,
        colormap='viridis',
        min_font_size=10
    ).generate(text)
    
    plt.figure(figsize=(8, 8), facecolor='white')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

# Function to combine all descriptions for a specific category
def make_string(category_name, data):
    text = ""
    for _, row in data.iterrows():
        if row['category'] == category_name:
            text += str(row['description']) + ' '
    return text

# Example usage
for category in le.classes_:
    combined_text = make_string(category, df_balanced)
    print_wordCloud(category, combined_text)
# Out:
# Word Cloud for art
# Word Cloud for business/finance
# Word Cloud for fantasy/horror
# Word Cloud for food
# Word Cloud for history
# Word Cloud for religion/spirituality
# Word Cloud for romance
# Word Cloud for science
# Word Cloud for science fiction
# Word Cloud for thriller

# %% [markdown]
# # Testing input against the model

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch, joblib
from sklearn.preprocessing import LabelEncoder
import joblib

# Save encoder after fitting labels
joblib.dump(le, "label_encoder.pkl")

model_path = "./final_model"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)
model.eval()

# Load the correct encoder
le = joblib.load("label_encoder.pkl")

def predict_genre(description, title="", authors=""):
    full_text = f"{title} by {authors}: {description}".strip()

    inputs = tokenizer(full_text, return_tensors="pt", truncation=True, padding="max_length", max_length=256)

    with torch.no_grad():
        outputs = model(**inputs)
        predicted_label = torch.argmax(outputs.logits, dim=1).item()

    return le.inverse_transform([predicted_label])[0]

# %%
# Imports and paths
import json
from pathlib import Path

testing = [
    "art_books", "business_books", "fantasy_novels", "history_books",
    "horror_novels", "religious_books", "romance_novels",
    "science_books", "science_fiction_novels", "spiritual_books",
    "thriller_novels", "food_books"
]

data = []

for path in testing:
    json_path = Path(f"../data/json_tests/{path}.json")

    with open(json_path, "r", encoding="utf-8") as f:
        file = json.load(f)

    data.append({path: file})  # store category → list of books
    print(f"Loaded {path}: {len(file)} items")


def pull_books(actual_val, tests):
    count = 0
    print(f"\nTesting category: {actual_val}\n")

    for book in tests:  # fixed 'test' → 'tests'
        predicted_genre = predict_genre(
            description=book["description"],
            title=book["title"],
            authors=book["authors"]
        )

        print(book["title"], "by", book["authors"], "-", predicted_genre)

        if predicted_genre == actual_val:
            count += 1

    print(f"\nAccuracy for {actual_val}: {count}/{len(tests)} = {(count/len(tests))*100:.2f}%")
# Out:
# Loaded art_books: 20 items
# Loaded business_books: 20 items
# Loaded fantasy_novels: 27 items
# Loaded history_books: 20 items
# Loaded horror_novels: 28 items
# Loaded religious_books: 20 items
# Loaded romance_novels: 19 items
# Loaded science_books: 20 items
# Loaded science_fiction_novels: 18 items
# Loaded spiritual_books: 10 items
# Loaded thriller_novels: 20 items
# Loaded food_books: 10 items

# %%
tests = data[0]["art_books"]
pull_books("art", tests)
# Out:
# Testing category: art
#
# The Alchemy of Light by Serafina Moretti - art
# Brushstrokes of History by Lorenzo Vega - art
# Sculpting the Soul by Helena Rivard - art
# The Color Revolution by Emilia Fontaine - art
# Canvas and Context by Theo Marwick - art
# Impressionism Unveiled by Clara Hastings - history
# Modernist Minds by Julian Crane - art
# The Art of the Forgotten by Nadia Soler - history
# Digital Brush by Marcus Eldridge - art
# Lines of Thought by Isabella Rey - art
# Art and Memory by Sophia Callen - art
# Textures of the Mind by Adrian Locke - art
# The Visual Language by Mara Fenwick - art
# Echoes in Paint by Lydia Harrow - art
# The Gallery Chronicles by Victor Lang - art
# Beyond the Frame by Cecilia Moore - art
# The Painter’s Journey by Elias Martel - art
# Art of the Invisible by Selene Rook - art
# The Sculptor’s Eye by Dahlia Venn - art
# Patterns of Civilization by Omar Kline - history
#
# Accuracy for art: 17/20 = 85.00%

# %%
tests = data[1]["business_books"]
pull_books("business/finance", tests)
# Out:
# Testing category: business/finance
#
# The Invisible Titans by Grant Kessler - business/finance
# Scaling Up Smart by Clara Dune - business/finance
# The Innovation Code by Marcus Eldridge - business/finance
# Profit and Purpose by Sophia Callen - business/finance
# The Lean Empire by Theo Marwick - business/finance
# Marketing Alchemy by Nadia Soler - business/finance
# Boardroom Battles by Julian Crane - business/finance
# Digital Dominance by Emilia Fontaine - business/finance
# The Entrepreneur’s Compass by Victor Raines - business/finance
# Capital Currents by Clara Hastings - business/finance
# The Strategy Lab by Lorenzo Vega - business/finance
# Disrupt or Die by Rena Kessler - business/finance
# Negotiation Mastery by Samantha Creed - business/finance
# The Productivity Paradox by Helena Rivard - business/finance
# Global Market Forces by Derek Vale - business/finance
# Culture Eats Strategy by Lydia Harrow - business/finance
# ...

# %%
tests = data[2]["fantasy_novels"]
pull_books('fantasy/horror', tests)
# Out:
# Testing category: fantasy/horror
#
# The Lord of the Rings by J.R.R. Tolkien - science fiction
# A Game of Thrones by George R.R. Martin - fantasy/horror
# The Name of the Wind by Patrick Rothfuss - fantasy/horror
# Mistborn: The Final Empire by Brandon Sanderson - science fiction
# The Wheel of Time: The Eye of the World by Robert Jordan - fantasy/horror
# The Way of Kings by Brandon Sanderson - fantasy/horror
# The Hobbit by J.R.R. Tolkien - science fiction
# The Silver Citadel by Ronan Graves - science fiction
# Thornborn by Elara Wyn - fantasy/horror
# Ashes of the First Dragon by Kellan Drake - fantasy/horror
# Mooncarver by Sera Valen - science fiction
# The Library of Fallen Names by Rowan Everhart - fantasy/horror
# Stormfeather by Myra Kael - fantasy/horror
# The Bone Harps by Tharin Morrow - fantasy/horror
# Blood of the Winter King by Varek Thorn - fantasy/horror
# Gilded Serpent by Isolde Ryn - fantasy/horror
# The Lantern of Echo Vale by Callum Stride - science fiction
# ...

# %%
tests = data[3]["history_books"]
pull_books('history', tests)
# Out:
# Testing category: history
#
# Empires of Sand by Richard Caldwell - history
# The Iron Web by Clara Hastings - business/finance
# Voices of Revolution by Nina Soler - history
# The Forgotten Front by Derek Vale - history
# Chronicles of Conquest by Marcus Trent - history
# Letters from the Past by Samantha Creed - history
# The Silk Roads by Elena Marwick - business/finance
# Revolutionary Minds by Lydia Harrow - history
# Empires of the Sea by Victor Raines - history
# The Shadow of Tyrants by Clara Dune - business/finance
# The Mapmakers’ Legacy by Theo Marwick - history
# Chronicles of the Commons by Nadia Soler - history
# Fires of Revolution by Julian Crane - history
# Bridges Across Time by Sophia Callen - history
# Empire Builders by Elias Martel - business/finance
# The Human Odyssey by Isabella Rey - history
# The Rise and Fall of Kingdoms by Rena Kessler - history
# Battles That Shaped the World by D. S. Marlow - history
# Pages of Power by Helena Rivard - science
# ...

# %%
tests = data[4]["horror_novels"]
pull_books('fantasy/horror', tests)
# Out:
# Testing category: fantasy/horror
#
# The House That Dreams by Mara Nix - science
# Skinwalker's Veil by Jonas Greeley - fantasy/horror
# Dead Air by Clive Rendon - thriller
# The Hollow Choir by Elise Rowan - fantasy/horror
# Rotwood by Parker Vane - fantasy/horror
# The Pale Visitor by Nadia Storn - art
# Thirteen Doors by Isaac Merrow - fantasy/horror
# Bloodletter by Vera Cross - thriller
# The Doll Beneath the Stairs by Carmine Blythe - fantasy/horror
# Quiet Hunger by Noah Drath - fantasy/horror
# The Faceless Widow by Iris Wane - fantasy/horror
# Basement 12 by Harper Sol - science
# The Unseen Roommate by Duncan Creed - thriller
# Mothlight by Elinor Shaw - fantasy/horror
# The Last Broadcast by Theo Marr - art
# Marrowstone by Declan Frost - fantasy/horror
# The Orchard of Bones by Lilith Dreer - food
# Listen for Me by Ruth Kelling - science
# Cold Guest by Milo Traverse - thriller
# When the Bell Rings by Brynn Hale - fantasy/horror
# ...

# %%
tests = data[5]["religious_books"]
pull_books('religion/spirituality', tests)
# Out:
# Testing category: religion/spirituality
#
# Paths of the Faithful by Samuel Hartman - religion/spirituality
# Sacred Symbols by Mara Nix - religion/spirituality
# The Devoted Heart by Elena Marwick - religion/spirituality
# Meditations Across Faiths by Sophia Callen - religion/spirituality
# The Pilgrim’s Journey by Victor Raines - religion/spirituality
# Sacred Texts Explained by Lydia Harrow - religion/spirituality
# Faith in Action by Julian Crane - religion/spirituality
# The Spirit of Ritual by Clara Hastings - religion/spirituality
# Divine Encounters by Nina Soler - religion/spirituality
# Paths to Enlightenment by Elena Marwick - religion/spirituality
# Holy Places of the World by Samantha Creed - religion/spirituality
# The Moral Compass by Theo Marwick - religion/spirituality
# Angels and Demons in Tradition by Helena Rivard - religion/spirituality
# Prayer and Reflection by Isabella Rey - religion/spirituality
# Faith and Reason by Omar Kline - religion/spirituality
# ...

# %%
tests = data[6]["romance_novels"]
pull_books('romance', tests)
# Out:
# Testing category: romance
#
# Hearts Entwined by Clara Dune - romance
# Love in the Highlands by Elena Marwick - romance
# The Secret Letter by Samantha Creed - romance
# A Dance Under the Stars by Sophia Callen - romance
# Whispers of the Heart by Lydia Harrow - religion/spirituality
# Summer of Second Chances by Julian Crane - romance
# Stolen Moments by Victor Raines - romance
# Letters Across the Sea by Helena Rivard - romance
# Once Upon a Winter by Nina Soler - romance
# Chasing Forever by Clara Hastings - romance
# Moonlit Promises by Elena Marwick - romance
# The Café of Dreams by Sophia Callen - romance
# A Symphony of Love by Marcus Eldridge - romance
# Beneath Cherry Blossoms by Lydia Harrow - romance
# The Artist’s Heart by Julian Crane - romance
# Seaside Confessions by Isabella Rey - romance
# A Timeless Embrace by Victor Raines - romance
# The Garden of Hearts by Helena Rivard - romance
# Unexpected Forever by Nina Soler - romance
#
# ...

# %%
tests = data[7]["science_books"]
pull_books('science', tests)
# Out:
# Testing category: science
#
# The Memory Code of Life by Dr. Marcus Velasquez - science
# Quantum Horizons by Elena Marwick - science fiction
# Starlight and Time by Julian Crane - science
# The Code of Genes by Sophia Callen - science
# Chaos in Nature by Marcus Eldridge - science
# Invisible Forces by Lydia Harrow - science
# The Brain’s Atlas by Isabella Rey - science
# Artificial Life by Omar Kline - art
# Particles and Paradox by Helena Rivard - science
# The Climate Equation by Victor Raines - science
# The Evolutionary Thread by Elena Marwick - science
# Genome Frontiers by Dr. Marcus Velasquez - science
# The Cosmos Within by Julian Crane - science
# Neural Revolutions by Sophia Callen - science
# Energy and Matter by Marcus Eldridge - science
# The Hidden Genome by Isabella Rey - science
# Time’s Fabric by Omar Kline - science
# The Microbial World by Helena Rivard - science
# Physics of the Impossible by Victor Raines - science
# ...

# %%
tests = data[8]["science_fiction_novels"]
pull_books('science fiction', tests)
# Out:
# Testing category: science fiction
#
# The Quantum Paradox by A. J. Fields - science fiction
# The Oracle Machine by N. Reyes - science fiction
# Echoes of Selene by Marin Holt - science fiction
# Echoes of Selene by Marin Holt - science fiction
# Echoes of Selene by Marin Holt - science fiction
# The Last Archive by Dorian Kessler - science fiction
# Neon Exodus by Kai Donovan - fantasy/horror
# Planetfall Protocol by Rhea Sundstrom - science fiction
# The Chrono Harvesters by Lewis Arden - science fiction
# Singularity’s Children by M. Vega - science
# The Rift Below by Helena Marr - science fiction
# Starlight Dominion by Tarek Monroe - science fiction
# Red Mars by Kim Stanley Robinson - science fiction
# Altered Carbon by Richard K. Morgan - science fiction
# Foundation by Isaac Asimov - science fiction
# Ready Player One by Ernest Cline - science fiction
# The Three-Body Problem by Liu Cixin - science fiction
# Children of Time by Adrian Tchaikovsky - science
#
# ...

# %%
tests = data[9]["spiritual_books"]
pull_books('religion/spirituality', tests)
# Out:
# Testing category: religion/spirituality
#
# The Power of Now by Eckhart Tolle - religion/spirituality
# A New Earth by Eckhart Tolle - religion/spirituality
# The Four Agreements by Don Miguel Ruiz - religion/spirituality
# The Untethered Soul by Michael A. Singer - religion/spirituality
# The Seat of the Soul by Gary Zukav - religion/spirituality
# Autobiography of a Yogi by Paramahansa Yogananda - religion/spirituality
# Man's Search for Meaning by Viktor E. Frankl - religion/spirituality
# Be Here Now by Ram Dass - religion/spirituality
# The Seven Spiritual Laws of Success by Deepak Chopra - business/finance
# The Road Less Traveled by M. Scott Peck - religion/spirituality
#
# Accuracy for religion/spirituality: 9/10 = 90.00%

# %%
tests = data[10]["thriller_novels"]
pull_books('thriller', tests)
# Out:
# Testing category: thriller
#
# Shattered Silence by K. L. Monroe - thriller
# The Vanishing Hour by Derek Vale - thriller
# Ciphered Lies by Nina Hawke - thriller
# Edge of Deception by Marcus Trent - thriller
# The Lazarus Protocol by Alicia Frost - science fiction
# Under the Crimson Sky by Victor Raines - thriller
# Bloodline of Secrets by Samantha Creed - thriller
# The 7th Witness by Jonas Keane - thriller
# Fractured Alibi by Lydia Marr - thriller
# The Silent Network by Rory Vance - thriller
# Hidden in Plain Sight by Clara Dune - thriller
# The Devil’s Ledger by Ethan Cross - thriller
# The Final Gambit by Monique Lane - thriller
# Veil of Shadows by Harper Quinn - thriller
# Twisted Motive by D. S. Marlow - thriller
# The Forgotten Room by Isaac Vale - fantasy/horror
# Vanishing Point by Rena Kessler - thriller
# Crimson Echo by Vera Stane - thriller
# Edge of Sanity by Theo Marr - thriller
# Darkwater Protocol by Elinor Shaw - thriller
#
# ...

# %%
tests = data[11]["food_books"]
pull_books('food', tests)
# Out:
# Testing category: food
#
# Salt: A World History by Mark Kurlansky - history
# Modernist Cuisine by Nathan Myhrvold, Chris Young, and Maxime Bilet - food
# The Omnivore's Dilemma by Michael Pollan - food
# Kitchen Confidential by Anthony Bourdain - food
# On Food and Cooking: The Science and Lore of the Kitchen by Harold McGee - food
# Animal, Vegetable, Miracle by Barbara Kingsolver - food
# Taste: My Life Through Food by Stanley Tucci - food
# The Taste of Country Cooking by Edna Lewis - food
# The Third Plate by Dan Barber - food
# Heat by Bill Buford - food
#
# Accuracy for food: 9/10 = 90.00%
